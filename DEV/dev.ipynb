# %%
import pandas as pd
import os 
from loguru import logger

# %%
CSV_FILE_PATH = "/quotes_db.csv"

# %%
def write_db(df: pd.DataFrame):
    df.to_csv(CSV_FILE_PATH, index=True, index_label='id')

def read_db()->pd.DataFrame:
    df = pd.read_csv(CSV_FILE_PATH, index_cols='id')
    return df

def initialize_db():
    df = pd.DataFrame(columns=['id', 'text'])
    df = df.set_index('id')
    write_db(df)


initialize_db()

# %%
"toto" + "tata"
# Out:
# 'tototata'

# %%
decimal_number = 1.0
binary_representation = format(decimal_number, '.30f')  # 30 decimal places
print(f"Decimal: {decimal_number+decimal_number}\nBinary: {binary_representation}")
# Out:
# Decimal: 2.0
# Binary: 1.000000000000000000000000000000
